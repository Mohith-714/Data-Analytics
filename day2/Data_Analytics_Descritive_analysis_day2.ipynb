# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/fitness_tracker.csv')

member_names = df['user_id'].astype(str).tolist()
ages = df['age'].tolist()
workout_hours = df['workout_duration_minutes'].tolist()
calories_burned = df['calories_burned'].tolist()

average_workout = sum(workout_hours)/len(workout_hours)
print("Average Workout Hours:",average_workout)

average_calories = sum(calories_burned)/len(calories_burned)
print("Average Calories Burned:",average_calories)

highest_calories = max(calories_burned)
print("Highest Calories Burned:",highest_calories)

lowest_calories = min(calories_burned)
print("Lowest Calories Burned:",lowest_calories)

median_calories = statistics.median(calories_burned)
print("Median Calories:",median_calories)

std_dev = statistics.stdev(calories_burned)
print("Standard Deviation:",std_dev)

index_highest = calories_burned.index(highest_calories)
print("Member with Highest Calories Burned:",member_names[index_highest])

index_lowest = calories_burned.index(lowest_calories)
print("Member with Lowest Calories Burned:",member_names[index_lowest])


plt.figure(figsize=(10, 6))
plt.bar(member_names, calories_burned)
plt.xlabel("Member Names (User ID)")
plt.ylabel("Calories Burned")
plt.title("Fitness Analysis - Calories Burned (Bar Plot)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(member_names, calories_burned)
plt.xlabel("Member Names (User ID)")
plt.ylabel("Calories Burned")
plt.title("Fitness Analysis - Calories Burned (Scatter Plot)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Average Workout Hours: 45.2585
# Average Calories Burned: 616.6891750000001
# Highest Calories Burned: 900.0
# Lowest Calories Burned: 120.0
# Median Calories: 629.8
# Standard Deviation: 211.02731819026422
# Member with Highest Calories Burned: 1860
# Member with Lowest Calories Burned: 1466

# %%
import statistics
member_names=["Aman","Riya","Karan","Sneha","Rahul"]
ages=[22,25,24,23,26]
workout_hours=[2,1.5,2.5,1,3]
calories_burned=[500,350,600,300,750]
print("-----Fitness Center Dataset-----")
for i in range(len(member_names)):
  print(member_names[i],
        ages[i],
        workout_hours[i],
        calories_burned[i])
average_workout=sum(workout_hours)/len(workout_hours)
print("Average Workout Hours:",average_workout)
average_calories=sum(calories_burned)/len(calories_burned)
print("Average Calories Burned:",average_calories)
highest_calories=max(calories_burned)
print("Highest Calories Burned:",highest_calories)
lowest_calories=min(calories_burned)
print("Lowest Calories Burned:",lowest_calories)
median_calories=statistics.median(calories_burned)
print("Median Calories:",median_calories)
std_dev=statistics.stdev(calories_burned)
print("Standard Deviation:",std_dev)
index=calories_burned.index(highest_calories)
print("Member with Highest Calories Burned:",member_names[index])
index=calories_burned.index(lowest_calories)
print("Member with Lowest Calories Burned:",member_names[index])
import matplotlib.pyplot as plt
plt.bar(member_names,calories_burned)
plt.xlabel("Member Names")
plt.ylabel("Calories Burned")
plt.title("Fitness Analysis")
plt.show()
plt.scatter(member_names,calories_burned)
plt.xlabel("Member Names")
plt.ylabel("Calories Burned")
plt.title("Fitness Analysis")
plt.show()
# Out:
# -----Fitness Center Dataset-----
# Aman 22 2 500
# Riya 25 1.5 350
# Karan 24 2.5 600
# Sneha 23 1 300
# Rahul 26 3 750
# Average Workout Hours: 2.0
# Average Calories Burned: 500.0
# Highest Calories Burned: 750
# Lowest Calories Burned: 300
# Median Calories: 500
# Standard Deviation: 183.71173070873834
# Member with Highest Calories Burned: Rahul
# Member with Lowest Calories Burned: Sneha

# %%
import statistics
member_names=["Aman","Riya","Karan","Sneha","Rahul"]
ages=[22,25,24,23,26]
workout_hours=[2,1.5,2.5,1,3]
calories_burned=[500.007,350.006,600.900,300.895,750.4509]
print("-----Fitness Center Dataset-----")
for i in range(len(member_names)):
  print(member_names[i],
        ages[i],
        workout_hours[i],
        calories_burned[i])
average_workout=sum(workout_hours)/len(workout_hours)
print("Average Workout Hours:",average_workout)
average_calories=sum(calories_burned)/len(calories_burned)
print("Average Calories Burned:",average_calories)
highest_calories=max(calories_burned)
print("Highest Calories Burned:",highest_calories)
lowest_calories=min(calories_burned)
print("Lowest Calories Burned:",lowest_calories)
median_calories=statistics.median(calories_burned)
print("Median Calories:",median_calories)
std_dev=statistics.stdev(calories_burned)
print("Standard Deviation:",std_dev)
index=calories_burned.index(highest_calories)
print("Member with Highest Calories Burned:",member_names[index])
index=calories_burned.index(lowest_calories)
print("Member with Lowest Calories Burned:",member_names[index])
import matplotlib.pyplot as plt
plt.bar(member_names,calories_burned)
plt.xlabel("Member Names")
plt.ylabel("Calories Burned")
plt.title("Fitness Analysis")
plt.show()
plt.scatter(member_names,calories_burned)
plt.xlabel("Member Names")
plt.ylabel("Calories Burned")
plt.title("Fitness Analysis")
plt.show()
# Out:
# -----Fitness Center Dataset-----
# Aman 22 2 500.007
# Riya 25 1.5 350.006
# Karan 24 2.5 600.9
# Sneha 23 1 300.895
# Rahul 26 3 750.4509
# Average Workout Hours: 2.0
# Average Calories Burned: 500.45178
# Highest Calories Burned: 750.4509
# Lowest Calories Burned: 300.895
# Median Calories: 500.007
# Standard Deviation: 183.743329059158
# Member with Highest Calories Burned: Rahul
# Member with Lowest Calories Burned: Sneha
