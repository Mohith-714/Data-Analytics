# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
marks=[70,68,50,90,87]
hours=[2,4,5,3,1]
print("Mean",np.mean(marks))
print("Median",np.median(marks))
print("Standard Deviation",np.std(marks))
print("Variance",np.var(marks))
print("Correlation",np.corrcoef(marks,hours))
print("Range",np.ptp(marks))
plt.figure(figsize=(8, 6))
sns.barplot(x=hours, y=marks, hue=hours, palette='viridis', legend=False)
plt.title('Marks vs Hours Studied')
plt.xlabel('Hours Studied')
plt.ylabel('Marks')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Mean 73.0
# Median 70.0
# Standard Deviation 14.477568856683085
# Variance 209.6
# Correlation [[ 1.         -0.74239143]
#  [-0.74239143  1.        ]]
# Range 40

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
marks=[40,70,55,68,80]
hours=[2,3,1,4,5]
print("Mean",np.mean(marks))
print("Median",np.median(marks))
print("Standard Deviation",np.std(marks))
print("Variance",np.var(marks))
print("Correlation",np.corrcoef(marks,hours))
print("Range",np.ptp(marks))
plt.figure(figsize=(8, 6))
sns.barplot(x=hours, y=marks, hue=hours, palette='viridis', legend=False)
plt.title('Marks vs Hours Studied')
plt.xlabel('Hours Studied')
plt.ylabel('Marks')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Mean 62.6
# Median 68.0
# Standard Deviation 13.821722034536796
# Variance 191.03999999999996
# Correlation [[1.         0.79808187]
#  [0.79808187 1.        ]]
# Range 40

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
marks=[40,50,60,70,80]
hours=[1,2,3,4,5]
print("Mean",np.mean(marks))
print("Median",np.median(marks))
print("Standard Deviation",np.std(marks))
print("Variance",np.var(marks))
print("Correlation",np.corrcoef(marks,hours))
print("Range",np.ptp(marks))
plt.figure(figsize=(8, 6))
sns.barplot(x=hours, y=marks, hue=hours, palette='viridis', legend=False)
plt.title('Marks vs Hours Studied')
plt.xlabel('Hours Studied')
plt.ylabel('Marks')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Mean 60.0
# Median 60.0
# Standard Deviation 14.142135623730951
# Variance 200.0
# Correlation [[1. 1.]
#  [1. 1.]]
# Range 40

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
marks=[86,65,79,60,57]
hours=[5,2,3,4,1]
print("Mean",np.mean(marks))
print("Median",np.median(marks))
print("Standard Deviation",np.std(marks))
print("Variance",np.var(marks))
print("Correlation",np.corrcoef(marks,hours))
print("Range",np.ptp(marks))
plt.figure(figsize=(8, 6))
sns.barplot(x=hours, y=marks, hue=hours, palette='viridis', legend=False)
plt.title('Marks vs Hours Studied')
plt.xlabel('Hours Studied')
plt.ylabel('Marks')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Mean 69.4
# Median 65.0
# Standard Deviation 11.217842929904126
# Variance 125.84
# Correlation [[1.        0.6681616]
#  [0.6681616 1.       ]]
# Range 29

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
marks=[59,45,69,54,70]
hours=[2,4,6,3,4]
print("Mean",np.mean(marks))
print("Median",np.median(marks))
print("Standard Deviation",np.std(marks))
print("Variance",np.var(marks))
print("Correlation",np.corrcoef(marks,hours))
print("Range",np.ptp(marks))
plt.figure(figsize=(8, 6))
sns.barplot(x=hours, y=marks, hue=hours, palette='viridis', legend=False)
plt.title('Marks vs Hours Studied')
plt.xlabel('Hours Studied')
plt.ylabel('Marks')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Mean 59.4
# Median 59.0
# Standard Deviation 9.3936148526539
# Variance 88.23999999999998
# Correlation [[1.         0.40763797]
#  [0.40763797 1.        ]]
# Range 25
